# %% [markdown]
# # KDE plot of parameter estimates

# %%
import os
from tempfile import template

import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

# %%
COEF_VAR = 'b'
xaxisrange = [-2, 2]

# %%
# DATA_PATH = '../xling/multiple-others-rescaled-tdelta/reports/all.parquet'
DATA_PATH = '../xling/multiple-others-k-steps-after-1/reports/all.parquet'

NULL_PARAMS = '../../4-POWER-LAW-SCALING/reports/null.csv'

REPORTS_PATH = 'reports'
if not os.path.exists(REPORTS_PATH):
    os.mkdir(REPORTS_PATH)

DIGITAL_EXCLUSIVE_PATH = os.path.join(REPORTS_PATH, 'website')
if not os.path.exists(DIGITAL_EXCLUSIVE_PATH):
    os.mkdir(DIGITAL_EXCLUSIVE_PATH)

PUBLICATION_READY_PATH = os.path.join(REPORTS_PATH, 'pub')
if not os.path.exists(PUBLICATION_READY_PATH):
    os.mkdir(PUBLICATION_READY_PATH)

# %%
df = pd.read_parquet(DATA_PATH)
df.head()
# Out:
#      corpus lang                                   cid  \
# 0  callhome  deu  xling-callhome-deu-callhome-deu-6692
# 1  callhome  deu  xling-callhome-deu-callhome-deu-6692
# 2  callhome  deu  xling-callhome-deu-callhome-deu-6692
# 3  callhome  deu  xling-callhome-deu-callhome-deu-6692
# 4   finchat  fin      xling-finchat-fin-finchat-fin-63
#
#                             speaker   self         a         b      k
# 0  callhome-deu-callhome-deu-6692-A   True  0.000013 -0.379041  13931
# 1  callhome-deu-callhome-deu-6692-A  False  0.000011 -0.273302  12738
# 2  callhome-deu-callhome-deu-6692-B  False  0.000017 -0.468889  12117
# 3  callhome-deu-callhome-deu-6692-B   True  0.000025 -0.495063  10914
# 4                 finchat-fin-63-54   True  0.000434  0.437574     36

# %%
# null_vals = pd.read_csv(NULL_PARAMS)
# null_vals = {se: v for se,v in null_vals[['self', 'b']].values}
# # null_vals

# %%
((df[COEF_VAR].values >= -2) & (df[COEF_VAR].values <= 2)).mean()
# Out:
# np.float64(0.9953335855719511)

# %% [markdown]
# ## Visualizing results

# %%
import plotly.graph_objects as go
import plotly.figure_factory as ff

# %% [markdown]
# ## All data

# %%
hist_data = [
    df[COEF_VAR].loc[df['self']].values,
    df[COEF_VAR].loc[~df['self']].values,
]

groups = [
    'sp(x) = sp(y)',
    'sp(x) ≠ sp(y)',
]

colors = [
    '#FFC30B',
    '#0041C2'
]

# %%
fig1 = ff.create_distplot(
    hist_data=hist_data,
    group_labels=groups,
    colors=colors,
    show_hist=False
)

fig1.update_layout(
    template='ygridoff',
    yaxis_title='Kernel Density Estimate (KDE)'
)

# %%
fig1.write_html(os.path.join(DIGITAL_EXCLUSIVE_PATH, 'xling-all-data.html'))
fig1.update_xaxes(range=xaxisrange)
fig1.write_html(os.path.join(PUBLICATION_READY_PATH, 'xling-all-data.html'))
fig1.write_image(os.path.join(PUBLICATION_READY_PATH, 'xling-all-data..png'), scale=5)

# %% [markdown]
# ### by corpus

# %%
corpus_col = 'lang'

# %%
figs = []

# %%
for corpus in df[corpus_col].unique():
    sub = df.loc[df[corpus_col].isin([corpus])]

    hist_data = [
        sub[COEF_VAR].loc[sub['self']].values,
        sub[COEF_VAR].loc[~sub['self']].values,
    ]

    groups = [
        'sp(x) = sp(y)',
        'sp(x) ≠ sp(y)',
    ]

    colors = [
        '#FFC30B',
        '#0041C2'
    ]

    figs += [
        ff.create_distplot(
            hist_data=hist_data,
            group_labels=groups,
            colors=colors,
            show_hist=False
        )
    ]
    # figs[-1].update_xaxes(range=[-1,1])
    figs[-1].update_layout(template='ygridoff')

# %%
for corpus, plot in zip(df[corpus_col].unique(), figs):
    print(corpus)
    plot.show()
    plot.write_html(os.path.join(DIGITAL_EXCLUSIVE_PATH, 'xling-'+corpus+'.html'))
    plot.update_layout(showlegend=False)
    plot.update_xaxes(range=xaxisrange)
    plot.write_html(os.path.join(PUBLICATION_READY_PATH, 'xling-'+corpus+'.html'))
    plot.write_image(os.path.join(PUBLICATION_READY_PATH, 'xling-'+corpus+'.png'), scale=5)
# Out:
# deu
# fin
# cro
# ko
# eng
# spa
# fra
# yid
# zho
