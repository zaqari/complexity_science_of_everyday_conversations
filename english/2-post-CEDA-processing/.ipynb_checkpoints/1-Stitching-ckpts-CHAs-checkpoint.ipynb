# %% [markdown]
# # Stitching together `.cha` files from the checkpoints
#
# Perhaps inadvertently, I've saved the outputs for each conversation as a CEDA checkpoint. We need to iterate through them and stitch together the final file for analysis.

# %%
import os
import torch
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

# %%
DATA_PATH = '../data'

INPUT_PATH = os.path.join(DATA_PATH, 'chas-ckpts')

OUTPUT_PATH = os.path.join(DATA_PATH, 'lme_ready')
if not os.path.exists(OUTPUT_PATH):
    os.mkdir(OUTPUT_PATH)

OUTPUT_NAME = os.path.join(OUTPUT_PATH,'cha-coraal-ceda-analysis.tsv')

# %%
def grab_all_files(PATH, file_type='.cha'):
    files = [
        [
            os.path.join(root, f) for f in files 
            if f.endswith(file_type) and (not f.startswith('._'))
        ] 
        for root, _, files in os.walk(PATH) 
    ]
    return sum(files, [])

# %% [markdown]
# ## Grabbing each file and creating a merged dataframe

# %%
files = [f for f in grab_all_files(DATA_PATH, 'coraal.csv.pt') if (not f.startswith('.')) and ('cha_corpus' in f)]
print(files)
# Out:
# ['data/chas-ckpts/graph-obj-cha_corpus-coraal.csv.pt']

# %%
df_ = []
for f in tqdm(files):
    ckpt = torch.load(f)
    df = pd.DataFrame(ckpt['meta_data'])
    
    # number of tokens per text
    df['nx'] = ckpt['N'][:,0].tolist()
    df['ny'] = ckpt['N'][:,1].tolist()
    
    # CE values
    df['Hxy'] = ckpt['M'][:,0].tolist()
    df['Hyx'] = ckpt['M'][:,1].tolist()
    
    df_ += [df]

df = pd.concat(df_, ignore_index=True)
print(df.shape)
df.head()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# (11936993, 20)
#    document_line_no  x_turn_id                         x_speaker       bullet  \
# 0                10          1  se0-ag1-se0-ag1-se0_ag1_f_01-PAR  [315, 2335]
# 1                10          1  se0-ag1-se0-ag1-se0_ag1_f_01-PAR  [315, 2335]
# 2                10          1  se0-ag1-se0-ag1-se0_ag1_f_01-PAR  [315, 2335]
# 3                10          1  se0-ag1-se0-ag1-se0_ag1_f_01-PAR  [315, 2335]
# 4                10          1  se0-ag1-se0-ag1-se0_ag1_f_01-PAR  [315, 2335]
#
#                                                  wor recipient  \
# 0  they 315_635 talking 635_715 about 715_83...     ADULT
# 1  they 315_635 talking 635_715 about 715_83...     ADULT
# 2  they 315_635 talking 635_715 about 715_83...     ADULT
# 3  they 315_635 talking 635_715 about 715_83...     ADULT
# 4  they 315_635 talking 635_715 about 715_83...     ADULT
#
#    overlapping_text   corpus               conversation_id  com  exp  \
# 0             False  se0-ag1  candor-cha_corpus-coraal.csv  NaN  NaN
# 1             False  se0-ag1  candor-cha_corpus-coraal.csv  NaN  NaN
# 2             False  se0-ag1  candor-cha_corpus-coraal.csv  NaN  NaN
# 3             False  se0-ag1  candor-cha_corpus-coraal.csv  NaN  NaN
# 4             False  se0-ag1  candor-cha_corpus-coraal.csv  NaN  NaN
#
#                                             raw_text  \
# 0  they talking about don't send him to his daddy .
# 1  they talking about don't send him to his daddy .
# 2  they talking about don't send him to his daddy .
# 3  they talking about don't send him to his daddy .
# 4  they talking about don't send him to his daddy .
#
#                           y_speaker  y_turn_id  y_utterance_delta_no   self  \
# 0  se0-ag1-se0-ag1-se0_ag1_f_01-INV          3                     0  False
# 1  se0-ag1-se0-ag1-se0_ag1_f_01-INV          7                     1  False
# 2  se0-ag1-se0-ag1-se0_ag1_f_01-INV          9                     2  False
# 3  se0-ag1-se0-ag1-se0_ag1_f_01-INV         11                     3  False
# 4  se0-ag1-se0-ag1-se0_ag1_f_01-INV         13                     4  False
#
#      nx    ny       Hxy       Hyx
# 0  12.0   4.0  3.494464  0.642247
# 1  12.0   8.0  3.357310  2.012856
# 2  12.0   5.0  3.574715  1.051937
# 3  12.0  12.0  3.328891  3.326899
# 4  12.0   3.0  3.600801  0.334642

# %% [markdown]
# #### Creating Add'l Regression Model Variables

# %%
# df['age_dif'] = df['x_age'] - df['y_age']
# df['pol_dif'] = df['x_politics'] - df['y_politics']
# df['status_dif'] = df['x_i_think_my_status'] - df['x_i_think_your_status']
# df['same_gender'] = (df['x_sex'] == df['y_sex']).astype(int)
# df['same_race'] = (df['x_race'] == df['y_race']).astype(int)
# df['same_edu'] = (df['x_edu'] == df['y_edu']).astype(int)
# df['t_delta'] = df['y_turn_id'] - df['x_turn_id']

# %%
# df[['age_dif', 'pol_dif', 'status_dif', 'same_gender', 'same_race', 't_delta', 'same_edu']].mean()

# %%
# df[['age_dif', 'pol_dif', 'status_dif', 'same_gender', 'same_race', 't_delta', 'same_edu']].median()

# %%
# df[['age_dif', 'pol_dif', 'status_dif', 'same_gender', 'same_race', 't_delta', 'same_edu']].std()

# %% [markdown]
# ## Save data

# %%
df.to_csv(
    OUTPUT_NAME,
    index=False, 
    encoding='utf-8',
    sep='\t'
)
