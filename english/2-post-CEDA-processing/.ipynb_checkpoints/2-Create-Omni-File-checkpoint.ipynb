# %% [markdown]
# # Create unified output file

# %%
import os
import torch
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

from datetime import datetime as dt

import warnings; warnings.filterwarnings('ignore')

# %%
DATA_PATH = '../data'

OUTPUT_PATH = os.path.join(DATA_PATH, 'lme_ready')

# post processing & ready for data visualization steps
FINAL_DOC = os.path.join(DATA_PATH, 'resids.parquet')
print(bool(os.path.exists(FINAL_DOC)))
# Out:
# True

# %%
def grab_all_files(PATH, file_type='.cha'):
    files = [
        [
            os.path.join(root, f) for f in files
            if f.endswith(file_type) and (not f.startswith('._'))
        ]
        for root, _, files in os.walk(PATH)
    ]
    return sum(files, [])

# %%
files = [f for f in grab_all_files(OUTPUT_PATH, '.tsv') if (not f.startswith('._'))]
print(files)
# Out:
# ['../data/lme_ready/cha-ceda-analysis.tsv', '../data/lme_ready/candor-ceda-analysis.tsv', '../data/lme_ready/cha-CABNC-ceda-analysis.tsv', '../data/lme_ready/grace-ceda-analysis.tsv', '../data/lme_ready/cha-MICASE-ceda-analysis.tsv', '../data/lme_ready/cha-coraal-ceda-analysis.tsv', '../data/lme_ready/null-ceda-analysis.tsv']

# %% [markdown]
# ## Processing the data
#
# Everything so far is saved into individual documents. This takes all of that and merges them into a single over-arching document, which is slightly less unwieldy.

# %%
start_from_turn = 5
min_acceptable_tokens = 5

# %%
df = []

# %%
for f in tqdm(files):
    print('\n', f)
    df += [pd.read_table(f, sep='\t')]

    if ('/cha-' in f) or ('grace-' in f):
        df[-1]['conversation_id'] = ['-'.join(sp.split('-')[:-1]) for sp in tqdm(df[-1]['x_speaker'])]

    elif '/candor-' in f:
        df[-1]['conversation_id'] = [sp.replace('.csv', '') for sp in tqdm(df[-1]['conversation_id'])]
        df[-1]['corpus'] = 'CANDOR'

    elif '/null-ceda' in f:
        df[-1]['conversation_id'] = ['-'.join(sp.split('-')[:-1]) for sp in tqdm(df[-1]['x_speaker'])]
        df[-1]['x_turn_id'] = [int(i.split('-')[-1]) for i in df[-1]['x_turn_id']]

    else:
        if 'conversation_id' in df[-1].columns:
            0
        else:
            df[-1]['conversation_id'] = f

    df[-1] = df[-1].loc[
        (df[-1]['nx'] >= min_acceptable_tokens)
        & (df[-1]['ny'] >= min_acceptable_tokens)
        & (df[-1]['x_turn_id'] >= start_from_turn)
    ]

    df[-1]['dyad'] = (df[-1]['x_speaker'] + '-' + df[-1]['y_speaker']).replace('\t', '-')
    df[-1]['turn_delta'] = (df[-1]['y_turn_id'] - df[-1]['x_turn_id'])
    df[-1] = df[-1][['Hxy', 'nx', 'ny', 'turn_delta', 'self',
                     'x_speaker',
                     'dyad', 'corpus', 'conversation_id', 'x_turn_id']]
    df[-1]['x_turn_id'] = df[-1]['conversation_id'].astype(str) + '-' + df[-1]['x_turn_id'].astype(str)

    df[-1]['null'] = bool('null-' in f)
df = pd.concat(df, ignore_index=True)

df.shape
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
#  ../data/lme_ready/cha-ceda-analysis.tsv
#   0%|          | 0/8028150 [00:00<?, ?it/s]
#  ../data/lme_ready/candor-ceda-analysis.tsv
#   0%|          | 0/429480 [00:00<?, ?it/s]
#  ../data/lme_ready/cha-CABNC-ceda-analysis.tsv
#   0%|          | 0/12723777 [00:00<?, ?it/s]
#  ../data/lme_ready/grace-ceda-analysis.tsv
#   0%|          | 0/1227208 [00:00<?, ?it/s]
#  ../data/lme_ready/cha-MICASE-ceda-analysis.tsv
#   0%|          | 0/8262622 [00:00<?, ?it/s]
#  ../data/lme_ready/cha-coraal-ceda-analysis.tsv
#   0%|          | 0/11936993 [00:00<?, ?it/s]
#  ../data/lme_ready/null-ceda-analysis.tsv
#   0%|          | 0/4110515 [00:03<?, ?it/s]
# (25424826, 11)

# %% [markdown]
# #### Checking on and dealing with null-distribution test results

# %%
df['null'].value_counts()
# Out:
# null
# False    23233133
# True      2191693
# Name: count, dtype: int64

# %%
df['x_turn_id'].loc[df['null']] = 'null-'+ df['x_turn_id'].loc[df['null']]

# %% [markdown]
# #### other checks

# %%
df['conversation_id'].nunique()
# Out:
# 2662

# %%
df.isna().sum()
# Out:
# Hxy                0
# nx                 0
# ny                 0
# turn_delta         0
# self               0
# x_speaker          0
# dyad               0
# corpus             0
# conversation_id    0
# x_turn_id          0
# null               0
# dtype: int64

# %%
df.head()
# Out:
#         Hxy    nx    ny  turn_delta   self             x_speaker  \
# 0  6.344819  20.0   6.0           1  False  GCSAusE-GCSAusE-01-S
# 1  6.000488  20.0   8.0           2  False  GCSAusE-GCSAusE-01-S
# 2  5.521488  20.0  13.0           4  False  GCSAusE-GCSAusE-01-S
# 3  6.057978  20.0   6.0           6  False  GCSAusE-GCSAusE-01-S
# 4  6.198739  20.0   6.0           7  False  GCSAusE-GCSAusE-01-S
#
#                                         dyad   corpus     conversation_id  \
# 0  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
# 1  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
# 2  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
# 3  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
# 4  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
#
#               x_turn_id   null
# 0  GCSAusE-GCSAusE-01-6  False
# 1  GCSAusE-GCSAusE-01-6  False
# 2  GCSAusE-GCSAusE-01-6  False
# 3  GCSAusE-GCSAusE-01-6  False
# 4  GCSAusE-GCSAusE-01-6  False

# %% [markdown]
# ## Relabel/add a column for per comparison sample $\Delta$
#
# In my initial work, it didn't really matter what number sample each value was. So it didn't matter if $t \pm 1$ was a self or other comment. Who cared. But for merging the data and for calculating allan variance, this is actually kinda important. So now I'm re-adding this in there.
#
# This all might be moot. There is very much a world in which what I actually need is a much simpler comparison between turn $\Delta$ values. Perhaps using Kolomogorov-Smirnov testing between each sample is sufficient? All I need, after all, is to prove that power-scaling is occurring here. And Allan-variance is just one test (though a well-trodden one) that can be used to assess that.

# %%
# df['groups'] = df['conversation_id'].astype(str) + '-' + df['x_turn_id'].astype(str)
df['groups'] = df['x_turn_id'].astype(str)

# %%
df['sample_delta'] = df.groupby(by=['groups', 'self']).cumcount() + 1

# %%
df.head()
# Out:
#         Hxy    nx    ny  turn_delta   self             x_speaker  \
# 0  6.344819  20.0   6.0           1  False  GCSAusE-GCSAusE-01-S
# 1  6.000488  20.0   8.0           2  False  GCSAusE-GCSAusE-01-S
# 2  5.521488  20.0  13.0           4  False  GCSAusE-GCSAusE-01-S
# 3  6.057978  20.0   6.0           6  False  GCSAusE-GCSAusE-01-S
# 4  6.198739  20.0   6.0           7  False  GCSAusE-GCSAusE-01-S
#
#                                         dyad   corpus     conversation_id  \
# 0  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
# 1  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
# 2  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
# 3  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
# 4  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
#
#               x_turn_id   null                groups  sample_delta
# 0  GCSAusE-GCSAusE-01-6  False  GCSAusE-GCSAusE-01-6             1
# 1  GCSAusE-GCSAusE-01-6  False  GCSAusE-GCSAusE-01-6             2
# 2  GCSAusE-GCSAusE-01-6  False  GCSAusE-GCSAusE-01-6             3
# 3  GCSAusE-GCSAusE-01-6  False  GCSAusE-GCSAusE-01-6             4
# 4  GCSAusE-GCSAusE-01-6  False  GCSAusE-GCSAusE-01-6             5

# %% [markdown]
# ## Tidying the data
#
# Making sure there aren't any erroneous `\t` elements in there.

# %%
# cleaning
for col in list(df):
    print(col)
    df[col] = [it.replace('\t', '') if isinstance(it,str) else it for it in tqdm(df[col])]

# %% [markdown]
# ## Save outputs
#
# Because that's the whole f'ing point.

# %%
# df.to_csv(FINAL_DOC, index=False, encoding='utf-8', sep='\t')

# %%
df.to_parquet(FINAL_DOC)

# %% [markdown]
# #### Check that data loads after saving

# %%
df_ = pd.read_parquet(FINAL_DOC)

# %%
del df_
