# %% [markdown]
# # Pre-processing a .CHA file for use in CE analysis

# %%
import os
import sys
import pandas as pd
from tqdm import tqdm

# %%
data_path = '../data'
chas_path = os.path.join(data_path, 'chas')
outputs_path = os.path.join(data_path, 'server_ready', 'cha_corpus-coraal.csv')

# %%
def grab_all_files(PATH, file_type='.cha'):
    files = [
        [
            os.path.join(root, f) for f in files 
            if f.endswith(file_type) and (not f.startswith('._'))
        ] 
        for root, _, files in os.walk(PATH) 
    ]
    return sum(files, [])

# %% [markdown]
# # Processing all CHA files
#
# Note: the package used here was developed by Prof. Garber. Cite via:
#
# Garber, L. (2019). CHA file python parser. Zenodo. https://doi.org/10.5281/zenodo.3364020

# %%
from shared.CHAFile import *

# %%
all_files = grab_all_files(chas_path)
len(all_files), all_files[0]
# Out:
# (271, '../data/chas/CORAAL/ATL/se0-ag1/se0_ag1_f_01.cha')

# %%
data = []
for f in all_files:
    
    chacha = ChaFile(f)
    meta_data_pieces = f.replace('.cha', '').split('/')
    
    for line in chacha.getLines():
        line['overlapping_text'] = bool(re.findall(r"(⌋|⌊|⌉|⌈)", line['text']))

        if meta_data_pieces[-2] in ['eng_n', 'eng_s']:
            line['corpus'] = meta_data_pieces[-3] + '-' + meta_data_pieces[-2]
        
        elif meta_data_pieces[-3] in ['instruction', 'CABNC', 'MICASE']:
            line['corpus'] = meta_data_pieces[-3] + '-' + meta_data_pieces[-2]
        
        else:
            line['corpus'] = meta_data_pieces[-2]
        
        line['conversation_id'] = line['corpus'] + '-' + meta_data_pieces[-1]
        
        data += [line.copy()]

data = pd.DataFrame(data)
# Out:
# Warning: no language found

# %%
data.shape
# Out:
# (202766, 12)

# %%
data.head()
# Out:
#    document_line_no  utterance_no speaker  \
# 0                10             1     PAR
# 1                12             2     PAR
# 2                14             3     INV
# 3                15             4     PAR
# 4                16             5     PAR
#
#                                                 text        bullet  \
# 0  they talking about don't send him to his daddy .    [315, 2335]
# 1       you just needta go file for child support .   [2675, 4695]
# 2                                           oh man .           NaN
# 3                                              bye .           NaN
# 4                                             why ?   [5355, 5855]
#
#                                                  wor recipient  \
# 0  they 315_635 talking 635_715 about 715_83...     ADULT
# 1  you 2675_2815 just 2815_2995 needta 2995_...     ADULT
# 2                                                NaN     ADULT
# 3                                                NaN     ADULT
# 4                                  why 5355_5855 ?     ADULT
#
#    overlapping_text   corpus       conversation_id  com  exp
# 0             False  se0-ag1  se0-ag1-se0_ag1_f_01  NaN  NaN
# 1             False  se0-ag1  se0-ag1-se0_ag1_f_01  NaN  NaN
# 2             False  se0-ag1  se0-ag1-se0_ag1_f_01  NaN  NaN
# 3             False  se0-ag1  se0-ag1-se0_ag1_f_01  NaN  NaN
# 4             False  se0-ag1  se0-ag1-se0_ag1_f_01  NaN  NaN

# %%
data['conversation_id'].nunique()
# Out:
# 213

# %% [markdown]
# ### Correcting utterances/removing CLAN specific formatting.

# %%
def corrected_text(text, contraction_replacement_nonce='CCOONNTTRRAACCTTIIOONN'):
    res = re.sub(r'\(\(.*?\)\)', ' ', str(text))
    # res = re.sub(r'\[.*?\]', ' ', res)
    
    # find contractions and preserve them . . .
    contractions = list(re.findall(r"\w+'\w+", res))
    for contraction in set(contractions):
        replacement = contraction.replace("'", contraction_replacement_nonce)
        res = res.replace(contraction, replacement)
    res = re.sub(r"(⌋|⌊|⌉|⌈)", '', res)
    res = res.replace(':', '')
    
    # remove numbers in parentheses (times???)
    res = re.sub(r'\(\d\.\d\)', ' ', res)
    
    # remove all other special characters.
    res = re.sub(r'[^\w\s]', ' ', res)
    
    res = re.sub(r'\s+', ' ', res).replace('[', ' ').replace(']', ' ').replace(contraction_replacement_nonce, "'")
    return res.strip()

# %%
data['raw_text'] = data['text'].values
data['text'] = [corrected_text(text) for text in tqdm(data['raw_text'].values)]
# Out:
# 100%|██████████| 202766/202766 [00:01<00:00, 159368.78it/s]

# %%
data[['corpus', 'raw_text', 'text']].head(n=6)
# Out:
#     corpus                                           raw_text  \
# 0  se0-ag1  they talking about don't send him to his daddy .
# 1  se0-ag1       you just needta go file for child support .
# 2  se0-ag1                                           oh man .
# 3  se0-ag1                                              bye .
# 4  se0-ag1                                             why ?
# 5  se0-ag1                                             why ?
#
#                                              text
# 0  they talking about don't send him to his daddy
# 1       you just needta go file for child support
# 2                                          oh man
# 3                                             bye
# 4                                             why
# 5                                             why

# %% [markdown]
# ## Create juxtaposed corpus: (x,y) pairs

# %%
max_turns_apart = 30

# %%
import warnings; warnings.filterwarnings("ignore")

corpus = []
for cid in tqdm(data['conversation_id'].unique()):
    sub = data.loc[data['conversation_id'].isin([cid])]
    sub_index = sub.index.values
    
    for i in sub_index:
        if i != sub_index[-1]:
            
            # speaker vs. other
            next_line_no = ( (sub_index > i) & (~sub['speaker'].isin([sub['speaker'].loc[i]])) ).values.nonzero()[0]
            next_line_no = sub_index[next_line_no][:(max_turns_apart+1)]
            
            # next_line_no = next_line_no[next_line_no <= (i + max_turns_apart)]
            for j,li in enumerate(next_line_no):
                d = data.loc[i].to_dict()
                
                d['next_speaker'] = data['speaker'].loc[li]
                d['next_text'] = data['text'].loc[li]
                d['next_utterance_no'] = data['utterance_no'].loc[li]
                d['next_utterance_delta_no'] = j
                
                corpus += [d]
            
            # speaker vs. self 
            next_line_no = ( (sub_index > i) & (sub['speaker'].isin([sub['speaker'].loc[i]])) ).values.nonzero()[0]
            next_line_no = sub_index[next_line_no][:(max_turns_apart+1)]
            # next_line_no = next_line_no[next_line_no <= (i + max_turns_apart)]
            for j,li in enumerate(next_line_no):
                d = data.loc[i].to_dict()
                
                d['next_speaker'] = data['speaker'].loc[li]
                d['next_text'] = data['text'].loc[li]
                d['next_utterance_no'] = data['utterance_no'].loc[li]
                d['next_utterance_delta_no'] = j
                
                corpus += [d]
# Out:
# 100%|██████████| 213/213 [10:22<00:00,  2.92s/it]

# %%
data = pd.DataFrame(corpus)
print(data.shape)
data.head()
# Out:
# (11936993, 17)
#    document_line_no  utterance_no speaker  \
# 0                10             1     PAR
# 1                10             1     PAR
# 2                10             1     PAR
# 3                10             1     PAR
# 4                10             1     PAR
#
#                                              text       bullet  \
# 0  they talking about don't send him to his daddy  [315, 2335]
# 1  they talking about don't send him to his daddy  [315, 2335]
# 2  they talking about don't send him to his daddy  [315, 2335]
# 3  they talking about don't send him to his daddy  [315, 2335]
# 4  they talking about don't send him to his daddy  [315, 2335]
#
#                                                  wor recipient  \
# 0  they 315_635 talking 635_715 about 715_83...     ADULT
# 1  they 315_635 talking 635_715 about 715_83...     ADULT
# 2  they 315_635 talking 635_715 about 715_83...     ADULT
# 3  they 315_635 talking 635_715 about 715_83...     ADULT
# 4  they 315_635 talking 635_715 about 715_83...     ADULT
#
#    overlapping_text   corpus       conversation_id  com  exp  \
# 0             False  se0-ag1  se0-ag1-se0_ag1_f_01  NaN  NaN
# 1             False  se0-ag1  se0-ag1-se0_ag1_f_01  NaN  NaN
# 2             False  se0-ag1  se0-ag1-se0_ag1_f_01  NaN  NaN
# 3             False  se0-ag1  se0-ag1-se0_ag1_f_01  NaN  NaN
# 4             False  se0-ag1  se0-ag1-se0_ag1_f_01  NaN  NaN
#
#                                             raw_text next_speaker  \
# 0  they talking about don't send him to his daddy .           INV
# 1  they talking about don't send him to his daddy .           INV
# 2  they talking about don't send him to his daddy .           INV
# 3  they talking about don't send him to his daddy .           INV
# 4  they talking about don't send him to his daddy .           INV
#
#                               next_text  next_utterance_no  \
# 0                                oh man                  3
# 1                 okay what's your name                  7
# 2                       Personname what                  9
# 3  okay and uh are you a male or female                 11
# 4                                laughs                 13
#
#    next_utterance_delta_no
# 0                        0
# 1                        1
# 2                        2
# 3                        3
# 4                        4

# %%
rename_columns = dict()
for col in data.columns:
    if col == 'text':
        rename_columns[col] = 'x_utterance'
    elif col == 'next_text':
        rename_columns[col] = 'y_utterance'
    elif 'next_' in col:
        rename_columns[col]  = col.replace('next', 'y')
    else:
        rename_columns[col] = col

# %%
data = data.rename(columns=rename_columns)
data.head()
# Out:
#    document_line_no  utterance_no speaker  \
# 0                10             1     PAR
# 1                10             1     PAR
# 2                10             1     PAR
# 3                10             1     PAR
# 4                10             1     PAR
#
#                                       x_utterance       bullet  \
# 0  they talking about don't send him to his daddy  [315, 2335]
# 1  they talking about don't send him to his daddy  [315, 2335]
# 2  they talking about don't send him to his daddy  [315, 2335]
# 3  they talking about don't send him to his daddy  [315, 2335]
# 4  they talking about don't send him to his daddy  [315, 2335]
#
#                                                  wor recipient  \
# 0  they 315_635 talking 635_715 about 715_83...     ADULT
# 1  they 315_635 talking 635_715 about 715_83...     ADULT
# 2  they 315_635 talking 635_715 about 715_83...     ADULT
# 3  they 315_635 talking 635_715 about 715_83...     ADULT
# 4  they 315_635 talking 635_715 about 715_83...     ADULT
#
#    overlapping_text   corpus       conversation_id  com  exp  \
# 0             False  se0-ag1  se0-ag1-se0_ag1_f_01  NaN  NaN
# 1             False  se0-ag1  se0-ag1-se0_ag1_f_01  NaN  NaN
# 2             False  se0-ag1  se0-ag1-se0_ag1_f_01  NaN  NaN
# 3             False  se0-ag1  se0-ag1-se0_ag1_f_01  NaN  NaN
# 4             False  se0-ag1  se0-ag1-se0_ag1_f_01  NaN  NaN
#
#                                             raw_text y_speaker  \
# 0  they talking about don't send him to his daddy .        INV
# 1  they talking about don't send him to his daddy .        INV
# 2  they talking about don't send him to his daddy .        INV
# 3  they talking about don't send him to his daddy .        INV
# 4  they talking about don't send him to his daddy .        INV
#
#                             y_utterance  y_utterance_no  y_utterance_delta_no
# 0                                oh man               3                     0
# 1                 okay what's your name               7                     1
# 2                       Personname what               9                     2
# 3  okay and uh are you a male or female              11                     3
# 4                                laughs              13                     4

# %%
data = data.rename(columns={'speaker':'x_speaker','utterance_no': 'x_turn_id', 'y_utterance_no': 'y_turn_id'})
data.head()
# Out:
#    document_line_no  x_turn_id x_speaker  \
# 0                10          1       PAR
# 1                10          1       PAR
# 2                10          1       PAR
# 3                10          1       PAR
# 4                10          1       PAR
#
#                                       x_utterance       bullet  \
# 0  they talking about don't send him to his daddy  [315, 2335]
# 1  they talking about don't send him to his daddy  [315, 2335]
# 2  they talking about don't send him to his daddy  [315, 2335]
# 3  they talking about don't send him to his daddy  [315, 2335]
# 4  they talking about don't send him to his daddy  [315, 2335]
#
#                                                  wor recipient  \
# 0  they 315_635 talking 635_715 about 715_83...     ADULT
# 1  they 315_635 talking 635_715 about 715_83...     ADULT
# 2  they 315_635 talking 635_715 about 715_83...     ADULT
# 3  they 315_635 talking 635_715 about 715_83...     ADULT
# 4  they 315_635 talking 635_715 about 715_83...     ADULT
#
#    overlapping_text   corpus       conversation_id  com  exp  \
# 0             False  se0-ag1  se0-ag1-se0_ag1_f_01  NaN  NaN
# 1             False  se0-ag1  se0-ag1-se0_ag1_f_01  NaN  NaN
# 2             False  se0-ag1  se0-ag1-se0_ag1_f_01  NaN  NaN
# 3             False  se0-ag1  se0-ag1-se0_ag1_f_01  NaN  NaN
# 4             False  se0-ag1  se0-ag1-se0_ag1_f_01  NaN  NaN
#
#                                             raw_text y_speaker  \
# 0  they talking about don't send him to his daddy .        INV
# 1  they talking about don't send him to his daddy .        INV
# 2  they talking about don't send him to his daddy .        INV
# 3  they talking about don't send him to his daddy .        INV
# 4  they talking about don't send him to his daddy .        INV
#
#                             y_utterance  y_turn_id  y_utterance_delta_no
# 0                                oh man          3                     0
# 1                 okay what's your name          7                     1
# 2                       Personname what          9                     2
# 3  okay and uh are you a male or female         11                     3
# 4                                laughs         13                     4

# %%
data['x_speaker'] = data['corpus'].astype(str) + '-' + data['conversation_id'].astype(str) + '-' + data['x_speaker'].astype(str)

data['y_speaker'] = data['corpus'].astype(str) + '-' + data['conversation_id'].astype(str) + '-' + data['y_speaker'].astype(str)

# %%
data['self'] = data['x_speaker'] == data['y_speaker']
data = data.sort_values(by=['corpus', 'conversation_id', 'x_turn_id', 'self', 'y_turn_id'])
data.index = range(len(data))

# %%
data[['corpus', 'x_utterance', 'y_utterance']].isna().mean()
# Out:
# corpus         0.0
# x_utterance    0.0
# y_utterance    0.0
# dtype: float64

# %%
# # corpus sanity check . . . make sure that conversation_ids are all unique 
# k = data[['conversation_id', 'corpus']].drop_duplicates()
# k['conversation_id'].nunique(), k['conversation_id'].nunique()/len(k)

# %%
data[['corpus', 'x_utterance', 'x_speaker', 'y_speaker', 'y_utterance', 'x_turn_id', 'y_turn_id']].head()
# Out:
#     corpus                                     x_utterance  \
# 0  se0-ag1  they talking about don't send him to his daddy
# 1  se0-ag1  they talking about don't send him to his daddy
# 2  se0-ag1  they talking about don't send him to his daddy
# 3  se0-ag1  they talking about don't send him to his daddy
# 4  se0-ag1  they talking about don't send him to his daddy
#
#                           x_speaker                         y_speaker  \
# 0  se0-ag1-se0-ag1-se0_ag1_f_01-PAR  se0-ag1-se0-ag1-se0_ag1_f_01-INV
# 1  se0-ag1-se0-ag1-se0_ag1_f_01-PAR  se0-ag1-se0-ag1-se0_ag1_f_01-INV
# 2  se0-ag1-se0-ag1-se0_ag1_f_01-PAR  se0-ag1-se0-ag1-se0_ag1_f_01-INV
# 3  se0-ag1-se0-ag1-se0_ag1_f_01-PAR  se0-ag1-se0-ag1-se0_ag1_f_01-INV
# 4  se0-ag1-se0-ag1-se0_ag1_f_01-PAR  se0-ag1-se0-ag1-se0_ag1_f_01-INV
#
#                             y_utterance  x_turn_id  y_turn_id
# 0                                oh man          1          3
# 1                 okay what's your name          1          7
# 2                       Personname what          1          9
# 3  okay and uh are you a male or female          1         11
# 4                                laughs          1         13

# %%
data.shape
# Out:
# (11936993, 18)

# %% [markdown]
# ## Save outputs for server operations.

# %%
data.to_csv(outputs_path, index=False, encoding='utf-8')
