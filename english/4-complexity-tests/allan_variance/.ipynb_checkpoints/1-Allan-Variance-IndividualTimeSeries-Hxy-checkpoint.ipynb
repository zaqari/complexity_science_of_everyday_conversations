# %% [markdown]
# # Calculating the Allan Variance for our dataset.
#
# This is ultimately the primary measurement for this particular study. Allan variance (AVAR) is the degree to which a signal varies over time. For the purposes of te current study, it's fairly simple to write it as
#
# (1)   $AVAR = \sigma^2(\tau) = \frac{1}{2\tau^2} \left\langle (H[x|y_{\Delta_{t+2}}] - \big[ 2 \cdot H[x|y_{\Delta_{t+1}}] \big] - H[x|y_{\Delta_{t}}])^2 \right\rangle$
#
# And we can test for various scaling relationships according to a regression of the log-transformed time $\Delta_t$ and the log-transformed $\sigma^2(\tau)$
#
# (2)   $\log \sigma^2(\tau) \sim \alpha \log \Delta_t$
#
# where $\alpha$ is the rate of exponential growth or decay.

# %%
import os
import re
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
from datetime import datetime as dt

import warnings; warnings.filterwarnings('ignore')

# %%
DATA_LOC = '../../data'

# path to processed and ready data
DATA_PATH = os.path.join(DATA_LOC, 'lme_ready')

# path to save data to on completion
VIS_PATH = os.path.join(DATA_LOC, 'web_vis')

# post processing & ready for data visualization steps
FINAL_DOC = os.path.join(DATA_LOC, 'resids.parquet')
print(os.path.exists(FINAL_DOC))
# Out:
# True

# %%
# Allan Var doc
allan_var = 'allan_var.parquet'

# %% [markdown]
# #### Load data

# %%
main_df = pd.read_parquet(FINAL_DOC)
main_df.shape
# Out:
# (25424826, 13)

# %%
main_df.head()
# Out:
#         Hxy    nx    ny  turn_delta   self             x_speaker  \
# 0  6.344819  20.0   6.0           1  False  GCSAusE-GCSAusE-01-S
# 1  6.000488  20.0   8.0           2  False  GCSAusE-GCSAusE-01-S
# 2  5.521488  20.0  13.0           4  False  GCSAusE-GCSAusE-01-S
# 3  6.057978  20.0   6.0           6  False  GCSAusE-GCSAusE-01-S
# 4  6.198739  20.0   6.0           7  False  GCSAusE-GCSAusE-01-S
#
#                                         dyad   corpus     conversation_id  \
# 0  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
# 1  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
# 2  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
# 3  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
# 4  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
#
#               x_turn_id   null                groups  sample_delta
# 0  GCSAusE-GCSAusE-01-6  False  GCSAusE-GCSAusE-01-6             1
# 1  GCSAusE-GCSAusE-01-6  False  GCSAusE-GCSAusE-01-6             2
# 2  GCSAusE-GCSAusE-01-6  False  GCSAusE-GCSAusE-01-6             3
# 3  GCSAusE-GCSAusE-01-6  False  GCSAusE-GCSAusE-01-6             4
# 4  GCSAusE-GCSAusE-01-6  False  GCSAusE-GCSAusE-01-6             5

# %% [markdown]
# #### Additional checks

# %%
main_df['conversation_id'].nunique()
# Out:
# 2662

# %%
main_df['null'].value_counts()
# Out:
# null
# False    23233133
# True      2191693
# Name: count, dtype: int64

# %%
main_df.loc[main_df['null']].head()
# Out:
#                Hxy    nx    ny  turn_delta   self                 x_speaker  \
# 23233133  8.396281  29.0  25.0           1  False  callfriend-eng_n-4175-M1
# 23233134  9.874767  29.0   5.0           3  False  callfriend-eng_n-4175-M1
# 23233135  8.867210  29.0  16.0           6  False  callfriend-eng_n-4175-M1
# 23233136  9.359125  29.0   5.0           8  False  callfriend-eng_n-4175-M1
# 23233137  8.732200  29.0   8.0          11  False  callfriend-eng_n-4175-M1
#
#                                                        dyad            corpus  \
# 23233133  callfriend-eng_n-4175-M1-callfriend-eng_n-4175-M2  callfriend-eng_n
# 23233134  callfriend-eng_n-4175-M1-callfriend-eng_n-4175-M2  callfriend-eng_n
# 23233135  callfriend-eng_n-4175-M1-callfriend-eng_n-4175-M2  callfriend-eng_n
# 23233136  callfriend-eng_n-4175-M1-callfriend-eng_n-4175-M2  callfriend-eng_n
# 23233137  callfriend-eng_n-4175-M1-callfriend-eng_n-4175-M2  callfriend-eng_n
#
#                 conversation_id                      x_turn_id  null  \
# 23233133  callfriend-eng_n-4175  null-callfriend-eng_n-4175-19  True
# 23233134  callfriend-eng_n-4175  null-callfriend-eng_n-4175-19  True
# 23233135  callfriend-eng_n-4175  null-callfriend-eng_n-4175-19  True
# 23233136  callfriend-eng_n-4175  null-callfriend-eng_n-4175-19  True
# 23233137  callfriend-eng_n-4175  null-callfriend-eng_n-4175-19  True
#
#                                  groups  sample_delta
# 23233133  null-callfriend-eng_n-4175-19             1
# 23233134  null-callfriend-eng_n-4175-19             2
# 23233135  null-callfriend-eng_n-4175-19             3
# 23233136  null-callfriend-eng_n-4175-19             4
# 23233137  null-callfriend-eng_n-4175-19             5

# %%
main_df.shape
# Out:
# (25424826, 13)

# %% [markdown]
# ### Some specific checks to ensure that null data is not a replica of regular data

# %%
main_df['null'].sum(), main_df['null'].mean()
# Out:
# (np.int64(2191693), np.float64(0.08620287116222546))

# %%
tids = main_df['groups'].loc[main_df['null']].unique()
tids
# Out:
# array(['null-callfriend-eng_n-4175-19', 'null-callfriend-eng_n-4175-31',
#        'null-callfriend-eng_n-4175-34', ...,
#        'null-se3-ag4-se3-ag4-se3_ag4_m_02_5-43',
#        'null-se3-ag4-se3-ag4-se3_ag4_m_02_5-46',
#        'null-se3-ag4-se3-ag4-se3_ag4_m_02_5-51'], dtype=object)

# %%
main_df['groups'].loc[main_df['groups'].isin([tid.replace('null-', '') for tid in tids]) & (~main_df['null'])].nunique() / len(tids)
# Out:
# 1.0

# %%
check_df = main_df.loc[main_df['groups'].isin(tids[:3])].copy()
check_df['groups'] = [tid.replace('null-', '') for tid in check_df['groups']]

check_df = pd.merge(
    left=check_df, left_on=['groups', 'self', 'sample_delta'],
    right=main_df[['groups', 'self', 'sample_delta', 'Hxy']].loc[~main_df['null']], right_on=['groups', 'self', 'sample_delta']
)
print(list(check_df))
check_df[['groups', 'Hxy_y', 'Hxy_x']].head(n=100)
# Out:
# ['Hxy_x', 'nx', 'ny', 'turn_delta', 'self', 'x_speaker', 'dyad', 'corpus', 'conversation_id', 'x_turn_id', 'null', 'groups', 'sample_delta', 'Hxy_y']
#                       groups     Hxy_y     Hxy_x
# 0   callfriend-eng_n-4175-19  9.724691  8.396281
# 1   callfriend-eng_n-4175-19  9.718081  9.874767
# 2   callfriend-eng_n-4175-19  9.729723  8.867210
# 3   callfriend-eng_n-4175-19  7.685726  9.359125
# 4   callfriend-eng_n-4175-19  8.528924  8.732200
# ..                       ...       ...       ...
# 95  callfriend-eng_n-4175-34  1.104928  1.002753
# 96  callfriend-eng_n-4175-34  0.714613  1.099127
# 97  callfriend-eng_n-4175-34  1.094481  1.085704
# 98  callfriend-eng_n-4175-34  1.062234  1.095373
# 99  callfriend-eng_n-4175-34  1.079867  1.065147
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Merge `copied doc` Method.

# %% [markdown]
# ### Regular Data

# %%
df = main_df.loc[~main_df['null']]

# %%
merge_columns = ['groups', 'self', 'sample_delta']

# %%
value_columns = ['Hxy']

# %% [markdown]
# #### First turn after the current turn

# %%
# make a copy of our df
df_ = df.copy()

# for every turn_delta, subtract it by one (so 2 => 1, et al.)
df_['sample_delta'] -= 1

# %%
# merge the copied doc with the actual doc using dyad ID, self,
#   and turn_delta as indexes
df = pd.merge(
    left=df, left_on=merge_columns,
    right=df_[merge_columns+value_columns], right_on=merge_columns,
    how='left'
)

# check the shape
print(df.shape)
df.isna().sum()
# Out:
# (23233133, 14)
# Hxy_x                    0
# nx                       0
# ny                       0
# turn_delta               0
# self                     0
# x_speaker                0
# dyad                     0
# corpus                   0
# conversation_id          0
# x_turn_id                0
# null                     0
# groups                   0
# sample_delta             0
# Hxy_y              1093574
# dtype: int64

# %% [markdown]
# #### Second turn after the current turn

# %%
# for every turn_delta, subtract it by one (so 2 => 1, et al.)
df_['sample_delta'] -= 1

# %%
# merge the copied doc with the actual doc using dyad ID, self,
#   and turn_delta as indexes
df = pd.merge(
    left=df, left_on=merge_columns,
    right=df_[merge_columns+value_columns], right_on=merge_columns,
    how='left'
)

# check the shape
print(df.shape)
df.isna().sum()
# Out:
# (23233133, 15)
# Hxy_x                    0
# nx                       0
# ny                       0
# turn_delta               0
# self                     0
# x_speaker                0
# dyad                     0
# corpus                   0
# conversation_id          0
# x_turn_id                0
# null                     0
# groups                   0
# sample_delta             0
# Hxy_y              1093574
# Hxy                2171042
# dtype: int64

# %% [markdown]
# #### Final checks

# %%
# check what row x column combos have NaNs
df.isna().sum()
# Out:
# Hxy_x                    0
# nx                       0
# ny                       0
# turn_delta               0
# self                     0
# x_speaker                0
# dyad                     0
# corpus                   0
# conversation_id          0
# x_turn_id                0
# null                     0
# groups                   0
# sample_delta             0
# Hxy_y              1093574
# Hxy                2171042
# dtype: int64

# %%
# get a sample of the NaN containing rows
df[['groups', 'sample_delta', 'Hxy_x', 'Hxy_y', 'Hxy']].loc[df['Hxy'].isna()].sample(n=10).head(n=10)
# Out:
#                                                      groups  sample_delta  \
# 2869387                                    callhome-4522-60            30
# 19473921                 se1-ag3-se1-ag3-se1_ag3_m_02_1-412            28
# 14127983  MICASE-office_hours-MICASE-office_hours-ofc280...            15
# 2932873                                   callhome-4574-387            21
# 97714                                 GCSAusE-GCSAusE-30-90             9
# 1278452                                SBCSAE-SBCSAE-51-500            22
# 2817228                                   callhome-4431-212            30
# 6568972                    CABNC-KBC-CABNC-KBC-KBCRE009-280            23
# 12564235              MICASE-lel-MICASE-lel-lel305ju092-305            31
# 14585578    MICASE-seminars-MICASE-seminars-sem475mx041-575            25
#
#               Hxy_x     Hxy_y  Hxy
# 2869387    3.721467       NaN  NaN
# 19473921   6.197931  5.766410  NaN
# 14127983   4.062446  4.293159  NaN
# 2932873    3.209975  2.987523  NaN
# 97714      1.230796       NaN  NaN
# 1278452    5.727911  5.664495  NaN
# 2817228    2.610899       NaN  NaN
# 6568972    6.255895       NaN  NaN
# 12564235   1.596344       NaN  NaN
# 14585578  16.938503       NaN  NaN

# %%
df = df.loc[~df['Hxy'].isna()]
df.shape
# Out:
# (21062091, 15)

# %%
df = df.rename(columns={'resid': 'residual'})
df = df.rename(columns={'Hxy_x': 'resid', 'Hxy_y': 'resid_1', 'Hxy': 'resid_2'})

# %%
df[['groups', 'resid', 'resid_1', 'resid_2']].head()
# Out:
#                  groups     resid   resid_1   resid_2
# 0  GCSAusE-GCSAusE-01-6  6.344819  6.000488  5.521488
# 1  GCSAusE-GCSAusE-01-6  6.000488  5.521488  6.057978
# 2  GCSAusE-GCSAusE-01-6  5.521488  6.057978  6.198739
# 3  GCSAusE-GCSAusE-01-6  6.057978  6.198739  5.745489
# 4  GCSAusE-GCSAusE-01-6  6.198739  5.745489  5.604022

# %% [markdown]
# #### Create Allan Variance Scale Parameter

# %%
group_cols = ['groups', 'self']
number_cols = ['sample_delta']

# %%
N = df[group_cols+number_cols].groupby(by=group_cols).agg('count').reset_index()
N = N.rename(columns={'sample_delta': 'N'})

# %%
df = pd.merge(
    left=df, left_on=group_cols,
    right=N, right_on=group_cols,
    how='left'
)
df.shape
# Out:
# (21062091, 16)

# %%
tau = df[group_cols+number_cols].groupby(by=group_cols).agg('max').reset_index()
tau = tau.rename(columns={'sample_delta': 'tau'})

# %%
df = pd.merge(
    left=df, left_on=group_cols,
    right=tau, right_on=group_cols,
    how='left'
)
df.shape
# Out:
# (21062091, 17)

# %%
df.head()
# Out:
#       resid    nx    ny  turn_delta   self             x_speaker  \
# 0  6.344819  20.0   6.0           1  False  GCSAusE-GCSAusE-01-S
# 1  6.000488  20.0   8.0           2  False  GCSAusE-GCSAusE-01-S
# 2  5.521488  20.0  13.0           4  False  GCSAusE-GCSAusE-01-S
# 3  6.057978  20.0   6.0           6  False  GCSAusE-GCSAusE-01-S
# 4  6.198739  20.0   6.0           7  False  GCSAusE-GCSAusE-01-S
#
#                                         dyad   corpus     conversation_id  \
# 0  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
# 1  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
# 2  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
# 3  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
# 4  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
#
#               x_turn_id   null                groups  sample_delta   resid_1  \
# 0  GCSAusE-GCSAusE-01-6  False  GCSAusE-GCSAusE-01-6             1  6.000488
# 1  GCSAusE-GCSAusE-01-6  False  GCSAusE-GCSAusE-01-6             2  5.521488
# 2  GCSAusE-GCSAusE-01-6  False  GCSAusE-GCSAusE-01-6             3  6.057978
# 3  GCSAusE-GCSAusE-01-6  False  GCSAusE-GCSAusE-01-6             4  6.198739
# 4  GCSAusE-GCSAusE-01-6  False  GCSAusE-GCSAusE-01-6             5  5.745489
#
#     resid_2   N  tau
# 0  5.521488  28   28
# 1  6.057978  28   28
# 2  6.198739  28   28
# 3  5.745489  28   28
# 4  5.604022  28   28

# %% [markdown]
# #### Calculate Allan $\sigma^2$

# %%
df = df.loc[~df['resid_2'].isna()]

# %%
df['allan_var'] = (1/(2*(df['tau']**2))) * ((df['resid_2'] - (2*df['resid_1']) + df['resid'])**2)

# %%
df.head()
# Out:
#       resid    nx    ny  turn_delta   self             x_speaker  \
# 0  6.344819  20.0   6.0           1  False  GCSAusE-GCSAusE-01-S
# 1  6.000488  20.0   8.0           2  False  GCSAusE-GCSAusE-01-S
# 2  5.521488  20.0  13.0           4  False  GCSAusE-GCSAusE-01-S
# 3  6.057978  20.0   6.0           6  False  GCSAusE-GCSAusE-01-S
# 4  6.198739  20.0   6.0           7  False  GCSAusE-GCSAusE-01-S
#
#                                         dyad   corpus     conversation_id  \
# 0  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
# 1  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
# 2  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
# 3  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
# 4  GCSAusE-GCSAusE-01-S-GCSAusE-GCSAusE-01-H  GCSAusE  GCSAusE-GCSAusE-01
#
#               x_turn_id   null                groups  sample_delta   resid_1  \
# 0  GCSAusE-GCSAusE-01-6  False  GCSAusE-GCSAusE-01-6             1  6.000488
# 1  GCSAusE-GCSAusE-01-6  False  GCSAusE-GCSAusE-01-6             2  5.521488
# 2  GCSAusE-GCSAusE-01-6  False  GCSAusE-GCSAusE-01-6             3  6.057978
# 3  GCSAusE-GCSAusE-01-6  False  GCSAusE-GCSAusE-01-6             4  6.198739
# 4  GCSAusE-GCSAusE-01-6  False  GCSAusE-GCSAusE-01-6             5  5.745489
#
#     resid_2   N  tau  allan_var
# 0  5.521488  28   28   0.000012
# 1  6.057978  28   28   0.000658
# 2  6.198739  28   28   0.000100
# 3  5.745489  28   28   0.000225
# 4  5.604022  28   28   0.000062

# %%
df['null'] = False

# %% [markdown]
# #### checkpoint

# %%
df.to_parquet('regular_data.parquet')

# %% [markdown]
# ### Null data

# %%
df = main_df.loc[main_df['null']]

# %%
merge_columns = ['groups', 'self', 'sample_delta']

# %%
value_columns = ['Hxy']

# %% [markdown]
# #### First turn after the current turn

# %%
# make a copy of our df
df_ = df.copy()

# for every turn_delta, subtract it by one (so 2 => 1, et al.)
df_['sample_delta'] -= 1

# %%
# merge the copied doc with the actual doc using dyad ID, self,
#   and turn_delta as indexes
df = pd.merge(
    left=df, left_on=merge_columns,
    right=df_[merge_columns+value_columns], right_on=merge_columns,
    how='left'
)

# check the shape
print(df.shape)
df.isna().sum()
# Out:
# (2191693, 14)
# Hxy_x                   0
# nx                      0
# ny                      0
# turn_delta              0
# self                    0
# x_speaker               0
# dyad                    0
# corpus                  0
# conversation_id         0
# x_turn_id               0
# null                    0
# groups                  0
# sample_delta            0
# Hxy_y              101185
# dtype: int64

# %% [markdown]
# #### Second turn after the current turn

# %%
# for every turn_delta, subtract it by one (so 2 => 1, et al.)
df_['sample_delta'] -= 1

# %%
# merge the copied doc with the actual doc using dyad ID, self,
#   and turn_delta as indexes
df = pd.merge(
    left=df, left_on=merge_columns,
    right=df_[merge_columns+value_columns], right_on=merge_columns,
    how='left'
)

# check the shape
print(df.shape)
df.isna().sum()
# Out:
# (2191693, 15)
# Hxy_x                   0
# nx                      0
# ny                      0
# turn_delta              0
# self                    0
# x_speaker               0
# dyad                    0
# corpus                  0
# conversation_id         0
# x_turn_id               0
# null                    0
# groups                  0
# sample_delta            0
# Hxy_y              101185
# Hxy                202348
# dtype: int64

# %% [markdown]
# #### Final checks

# %%
# check what row x column combos have NaNs
df.isna().sum()
# Out:
# Hxy_x                   0
# nx                      0
# ny                      0
# turn_delta              0
# self                    0
# x_speaker               0
# dyad                    0
# corpus                  0
# conversation_id         0
# x_turn_id               0
# null                    0
# groups                  0
# sample_delta            0
# Hxy_y              101185
# Hxy                202348
# dtype: int64

# %%
# get a sample of the NaN containing rows
df[['groups', 'sample_delta', 'Hxy_x', 'Hxy_y', 'Hxy']].loc[df['Hxy'].isna()].sample(n=10).head(n=10)
# Out:
#                                                     groups  sample_delta  \
# 1072446  null-MICASE-advising-MICASE-advising-adv700ju0...            24
# 1778678            null-se1-ag1-se1-ag1-se1_ag1_m_03_1-527            24
# 472583      null-CABNC-0missing-CABNC-0missing-KCGRE006-73            20
# 1859394            null-se1-ag3-se1-ag3-se1_ag3_m_02_2-154            26
# 694613               null-CABNC-KBH-CABNC-KBH-KBHRE00F-461            20
# 1672046            null-se0-ag3-se0-ag3-se0_ag3_f_03_1-832            21
# 1204997          null-MICASE-lel-MICASE-lel-lel320ju147-73             6
# 1716791            null-se0-ag4-se0-ag4-se0_ag4_f_02_1-263            44
# 345425                           null-SBCSAE-SBCSAE-48-598            22
# 1888372            null-se1-ag4-se1-ag4-se1_ag4_m_02_1-312            20
#
#              Hxy_x     Hxy_y  Hxy
# 1072446   7.360013       NaN  NaN
# 1778678   2.065610       NaN  NaN
# 472583   12.770847       NaN  NaN
# 1859394   2.071614       NaN  NaN
# 694613    1.396105       NaN  NaN
# 1672046   1.741669  1.740673  NaN
# 1204997   6.153245       NaN  NaN
# 1716791   2.894483       NaN  NaN
# 345425    1.310872       NaN  NaN
# 1888372   3.096557       NaN  NaN

# %%
df = df.loc[~df['Hxy'].isna()]
df.shape
# Out:
# (1989345, 15)

# %%
df = df.rename(columns={'resid': 'residual'})
df = df.rename(columns={'Hxy_x': 'resid', 'Hxy_y': 'resid_1', 'Hxy': 'resid_2'})

# %%
df[['groups', 'resid', 'resid_1', 'resid_2']].head()
# Out:
#                           groups     resid   resid_1   resid_2
# 0  null-callfriend-eng_n-4175-19  8.396281  9.874767  8.867210
# 1  null-callfriend-eng_n-4175-19  9.874767  8.867210  9.359125
# 2  null-callfriend-eng_n-4175-19  8.867210  9.359125  8.732200
# 3  null-callfriend-eng_n-4175-19  9.359125  8.732200  9.067421
# 4  null-callfriend-eng_n-4175-19  8.732200  9.067421  8.825766

# %% [markdown]
# #### Create Allan Variance Scale Parameter

# %%
group_cols = ['groups', 'self']
number_cols = ['sample_delta']

# %%
N = df[group_cols+number_cols].groupby(by=group_cols).agg('count').reset_index()
N = N.rename(columns={'sample_delta': 'N'})

# %%
df = pd.merge(
    left=df, left_on=group_cols,
    right=N, right_on=group_cols,
    how='left'
)
df.shape
# Out:
# (1989345, 16)

# %%
tau = df[group_cols+number_cols].groupby(by=group_cols).agg('max').reset_index()
tau = tau.rename(columns={'sample_delta': 'tau'})

# %%
df = pd.merge(
    left=df, left_on=group_cols,
    right=tau, right_on=group_cols,
    how='left'
)
df.shape
# Out:
# (1989345, 17)

# %%
df.head()
# Out:
#       resid    nx    ny  turn_delta   self                 x_speaker  \
# 0  8.396281  29.0  25.0           1  False  callfriend-eng_n-4175-M1
# 1  9.874767  29.0   5.0           3  False  callfriend-eng_n-4175-M1
# 2  8.867210  29.0  16.0           6  False  callfriend-eng_n-4175-M1
# 3  9.359125  29.0   5.0           8  False  callfriend-eng_n-4175-M1
# 4  8.732200  29.0   8.0          11  False  callfriend-eng_n-4175-M1
#
#                                                 dyad            corpus  \
# 0  callfriend-eng_n-4175-M1-callfriend-eng_n-4175-M2  callfriend-eng_n
# 1  callfriend-eng_n-4175-M1-callfriend-eng_n-4175-M2  callfriend-eng_n
# 2  callfriend-eng_n-4175-M1-callfriend-eng_n-4175-M2  callfriend-eng_n
# 3  callfriend-eng_n-4175-M1-callfriend-eng_n-4175-M2  callfriend-eng_n
# 4  callfriend-eng_n-4175-M1-callfriend-eng_n-4175-M2  callfriend-eng_n
#
#          conversation_id                      x_turn_id  null  \
# 0  callfriend-eng_n-4175  null-callfriend-eng_n-4175-19  True
# 1  callfriend-eng_n-4175  null-callfriend-eng_n-4175-19  True
# 2  callfriend-eng_n-4175  null-callfriend-eng_n-4175-19  True
# 3  callfriend-eng_n-4175  null-callfriend-eng_n-4175-19  True
# 4  callfriend-eng_n-4175  null-callfriend-eng_n-4175-19  True
#
#                           groups  sample_delta   resid_1   resid_2   N  tau
# 0  null-callfriend-eng_n-4175-19             1  9.874767  8.867210  17   17
# 1  null-callfriend-eng_n-4175-19             2  8.867210  9.359125  17   17
# 2  null-callfriend-eng_n-4175-19             3  9.359125  8.732200  17   17
# 3  null-callfriend-eng_n-4175-19             4  8.732200  9.067421  17   17
# 4  null-callfriend-eng_n-4175-19             5  9.067421  8.825766  17   17

# %% [markdown]
# #### Calculate Allan $\sigma^2$

# %%
df = df.loc[~df['resid_2'].isna()]

# %%
df['allan_var'] = (1/(2*(df['tau']**2))) * ((df['resid_2'] - (2*df['resid_1']) + df['resid'])**2)

# %%
df[['groups', 'resid', 'resid_1', 'resid_2', 'allan_var']].head(n=20)
# Out:
#                            groups     resid   resid_1   resid_2  allan_var
# 0   null-callfriend-eng_n-4175-19  8.396281  9.874767  8.867210   0.010693
# 1   null-callfriend-eng_n-4175-19  9.874767  8.867210  9.359125   0.003890
# 2   null-callfriend-eng_n-4175-19  8.867210  9.359125  8.732200   0.002166
# 3   null-callfriend-eng_n-4175-19  9.359125  8.732200  9.067421   0.001602
# 4   null-callfriend-eng_n-4175-19  8.732200  9.067421  8.825766   0.000576
# 5   null-callfriend-eng_n-4175-19  9.067421  8.825766  9.799860   0.002557
# 6   null-callfriend-eng_n-4175-19  8.825766  9.799860  9.738371   0.001855
# 7   null-callfriend-eng_n-4175-19  9.799860  9.738371  8.778589   0.001396
# 8   null-callfriend-eng_n-4175-19  9.738371  8.778589  8.320789   0.000436
# 9   null-callfriend-eng_n-4175-19  8.778589  8.320789  8.584559   0.000901
# 10  null-callfriend-eng_n-4175-19  8.320789  8.584559  8.618721   0.000091
# 11  null-callfriend-eng_n-4175-19  8.584559  8.618721  8.171370   0.000401
# 12  null-callfriend-eng_n-4175-19  8.618721  8.171370  8.362799   0.000706
# 13  null-callfriend-eng_n-4175-19  8.171370  8.362799  9.182179   0.000682
# 14  null-callfriend-eng_n-4175-19  8.362799  9.182179  8.814989   0.002436
# 15  null-callfriend-eng_n-4175-19  9.182179  8.814989  9.368731   0.001467
# 16  null-callfriend-eng_n-4175-19  8.814989  9.368731  8.922549   0.001730
# 17  null-callfriend-eng_n-4175-19  8.384868  8.841423  8.858796   0.000219
# 18  null-callfriend-eng_n-4175-19  8.841423  8.858796  8.634043   0.000066
# 19  null-callfriend-eng_n-4175-19  8.858796  8.634043  9.478838   0.001297

# %%
df['null'] = True

# %% [markdown]
# #### checkpoint

# %%
df.to_parquet('null_data.parquet')

# %% [markdown]
# # Save outputs

# %%
df = [pd.read_parquet('null_data.parquet'), pd.read_parquet('regular_data.parquet')]

# %% [markdown]
# #### Quick check that data is actually different.

# %%
df[0][['groups', 'resid', 'resid_1', 'resid_2', 'allan_var']].head(n=20)
# Out:
#                            groups     resid   resid_1   resid_2  allan_var
# 0   null-callfriend-eng_n-4175-19  8.396281  9.874767  8.867210   0.010693
# 1   null-callfriend-eng_n-4175-19  9.874767  8.867210  9.359125   0.003890
# 2   null-callfriend-eng_n-4175-19  8.867210  9.359125  8.732200   0.002166
# 3   null-callfriend-eng_n-4175-19  9.359125  8.732200  9.067421   0.001602
# 4   null-callfriend-eng_n-4175-19  8.732200  9.067421  8.825766   0.000576
# 5   null-callfriend-eng_n-4175-19  9.067421  8.825766  9.799860   0.002557
# 6   null-callfriend-eng_n-4175-19  8.825766  9.799860  9.738371   0.001855
# 7   null-callfriend-eng_n-4175-19  9.799860  9.738371  8.778589   0.001396
# 8   null-callfriend-eng_n-4175-19  9.738371  8.778589  8.320789   0.000436
# 9   null-callfriend-eng_n-4175-19  8.778589  8.320789  8.584559   0.000901
# 10  null-callfriend-eng_n-4175-19  8.320789  8.584559  8.618721   0.000091
# 11  null-callfriend-eng_n-4175-19  8.584559  8.618721  8.171370   0.000401
# 12  null-callfriend-eng_n-4175-19  8.618721  8.171370  8.362799   0.000706
# 13  null-callfriend-eng_n-4175-19  8.171370  8.362799  9.182179   0.000682
# 14  null-callfriend-eng_n-4175-19  8.362799  9.182179  8.814989   0.002436
# 15  null-callfriend-eng_n-4175-19  9.182179  8.814989  9.368731   0.001467
# 16  null-callfriend-eng_n-4175-19  8.814989  9.368731  8.922549   0.001730
# 17  null-callfriend-eng_n-4175-19  8.384868  8.841423  8.858796   0.000219
# 18  null-callfriend-eng_n-4175-19  8.841423  8.858796  8.634043   0.000066
# 19  null-callfriend-eng_n-4175-19  8.858796  8.634043  9.478838   0.001297

# %%
check_tids = [tid.replace('null-', '') for tid in df[0]['groups'].unique()[:10]]
df[1][['groups', 'resid', 'resid_1', 'resid_2', 'allan_var']].loc[df[1]['groups'].isin(check_tids)].head(n=20)
# Out:
#                            groups     resid   resid_1   resid_2     allan_var
# 1655892  callfriend-eng_n-4175-19  9.724691  9.718081  9.729723  3.149186e-07
# 1655893  callfriend-eng_n-4175-19  9.718081  9.729723  7.685726  3.994001e-03
# 1655894  callfriend-eng_n-4175-19  9.729723  7.685726  8.528924  7.878916e-03
# 1655895  callfriend-eng_n-4175-19  7.685726  8.528924  9.681519  9.047859e-05
# 1655896  callfriend-eng_n-4175-19  8.528924  9.681519  8.492232  5.183748e-03
# 1655897  callfriend-eng_n-4175-19  9.681519  8.492232  9.530680  4.690734e-03
# 1655898  callfriend-eng_n-4175-19  8.492232  9.530680  8.980171  2.386371e-03
# 1655899  callfriend-eng_n-4175-19  9.530680  8.980171  8.417046  1.504646e-07
# 1655900  callfriend-eng_n-4175-19  8.980171  8.417046  8.962903  1.162423e-03
# 1655901  callfriend-eng_n-4175-19  8.417046  8.962903  8.727501  5.769059e-04
# 1655902  callfriend-eng_n-4175-19  8.962903  8.727501  9.717264  1.418743e-03
# 1655903  callfriend-eng_n-4175-19  8.727501  9.717264  8.256520  5.675790e-03
# 1655904  callfriend-eng_n-4175-19  9.717264  8.256520  8.536731  2.864766e-03
# 1655905  callfriend-eng_n-4175-19  8.256520  8.536731  8.716812  9.476221e-06
# 1655906  callfriend-eng_n-4175-19  8.536731  8.716812  9.403948  2.430095e-04
# 1655907  callfriend-eng_n-4175-19  8.716812  9.403948  8.647976  1.968393e-03
# 1655908  callfriend-eng_n-4175-19  9.403948  8.647976  9.471071  2.356761e-03
# 1655909  callfriend-eng_n-4175-19  8.647976  9.471071  9.065016  1.427988e-03
# 1655910  callfriend-eng_n-4175-19  9.471071  9.065016  8.471387  3.325500e-05
# 1655911  callfriend-eng_n-4175-19  9.065016  8.471387  9.559801  2.674167e-03

# %% [markdown]
# #### Save data to final .parquet

# %%
df = pd.concat(df, ignore_index=True)

# %%
# df.to_csv(
#     allan_var,
#     index=False,
#     encoding='utf-8',
#     sep='\t'
# )
df.to_parquet(allan_var)

# %% [markdown]
# #### Clean up data

# %%
os.remove('null_data.parquet')
os.remove('regular_data.parquet')
