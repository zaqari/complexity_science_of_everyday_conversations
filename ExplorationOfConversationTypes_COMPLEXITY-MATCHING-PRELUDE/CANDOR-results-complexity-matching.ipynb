# %% [markdown]
# # Calculating the rate of kinds of conversations in the massive english dataset.

# %%
import os
import numpy as np
import pandas as pd

from scipy.stats import skewtest, chisquare, t

# stats in R
import rpy2.robjects as ro
from rpy2.robjects import Formula
from rpy2.robjects.conversion import localconverter
from rpy2.robjects import pandas2ri, default_converter, conversion

import pyarrow.parquet as pq
from tqdm.notebook import tqdm
import warnings; warnings.filterwarnings('ignore')

# %%
DATA_PATH = '../english/4-POWER-LAW-SCALING/reports'
candor_meta_data_path = '../english/data/all-candor-meta_data.csv'


parameter_values = os.path.join(DATA_PATH,'study-level-statistics.csv')
alpha_values = os.path.join(DATA_PATH, 'all.csv')

# %%
df = pd.read_csv(alpha_values)
print(df.shape)
df.head()
# Out:
# (23894, 7)
#   corpus                 cid                           speaker   self  \
# 0  CABNC  CABNC-KB0RE000-KB0  CABNC-CABNC-KB0RE000-KB0-KB0PSUN  False
# 1  CABNC  CABNC-KB0RE000-KB0  CABNC-CABNC-KB0RE000-KB0-KB0PSUN   True
# 2  CABNC  CABNC-KB0RE000-KB0    CABNC-CABNC-KB0RE000-KB0-PS002  False
# 3  CABNC  CABNC-KB0RE000-KB0    CABNC-CABNC-KB0RE000-KB0-PS002   True
# 4  CABNC  CABNC-KB0RE000-KB0    CABNC-CABNC-KB0RE000-KB0-PS006  False
#
#               a         b     k
# 0  2.240313e-04 -0.727759  1066
# 1  1.439414e-08  0.363082   136
# 2  1.320233e-03 -0.615558  3107
# 3  1.493614e-03 -0.797152  2556
# 4  5.985318e-04 -0.503047  2966

# %%
dfp = pd.read_csv(parameter_values)
dfp = dfp.rename(columns={'b': 'b_'})
dfp.head()
# Out:
#     self        b_       std      k        se      tstat    p
# 0  False -0.387600  0.943652  12019  0.008608 -45.030446  0.0
# 1   True -0.486513  1.104611  10719  0.010669 -45.599785  0.0

# %%
df = pd.merge(
    left=df,left_on=['self'],
    right=dfp[['self', 'b_']], right_on=['self'],
    how='left'
)

# %%
df['faster'] = df['b'] < df['b_']

# %% [markdown]
# ## Hypothesis test: Conversation Types are distributed equally.
#
# We wanted to test the assumption that all possible combinations of information scaling factors are equal. We thus tested
#
# $(\alpha_s < \bar{\alpha_s})\ \ \&\ \ (\alpha_o < \bar{\alpha_o})$ (Both are faster)
#
# $(\alpha_s < \bar{\alpha_s})\ \ \&\ \ (\alpha_o > \bar{\alpha_o})$ (Self is fast, other is slow)
#
# $(\alpha_s > \bar{\alpha_s})\ \ \&\ \ (\alpha_o < \bar{\alpha_o})$ (Self is slow, other is fast)
#
# $(\alpha_s > \bar{\alpha_s})\ \ \&\ \ (\alpha_o > \bar{\alpha_o})$ (Both are slower)

# %%
df['self'].sum()
# Out:
# np.int64(11290)

# %%
dfo = pd.merge(
    left=df.loc[df['self']], left_on=['corpus', 'cid', 'speaker'],
    right=df[['corpus', 'cid', 'speaker', 'faster', 'b']].loc[~df['self']], right_on=['corpus', 'cid', 'speaker'],
    how='left'
)
print(dfo.shape)
dfo.isna().sum()
# Out:
# (11290, 11)
# corpus       0
# cid          0
# speaker      0
# self         0
# a            0
# b_x          0
# k            0
# b_           0
# faster_x     0
# faster_y    49
# b_y         49
# dtype: int64

# %%
dfo = dfo.loc[~dfo['faster_y'].isna()]
dfo.head()
# Out:
#   corpus                 cid                           speaker  self  \
# 0  CABNC  CABNC-KB0RE000-KB0  CABNC-CABNC-KB0RE000-KB0-KB0PSUN  True
# 1  CABNC  CABNC-KB0RE000-KB0    CABNC-CABNC-KB0RE000-KB0-PS002  True
# 2  CABNC  CABNC-KB0RE000-KB0    CABNC-CABNC-KB0RE000-KB0-PS006  True
# 3  CABNC  CABNC-KB0RE001-KB0  CABNC-CABNC-KB0RE001-KB0-KB0PSUN  True
# 4  CABNC  CABNC-KB0RE001-KB0    CABNC-CABNC-KB0RE001-KB0-PS005  True
#
#               a       b_x     k        b_  faster_x faster_y       b_y
# 0  1.439414e-08  0.363082   136 -0.486513     False     True -0.727759
# 1  1.493614e-03 -0.797152  2556 -0.486513      True     True -0.615558
# 2  3.587024e-04 -0.430773  1953 -0.486513     False     True -0.503047
# 3  5.573154e-06 -0.930984   105 -0.486513      True     True -0.622488
# 4  5.494917e-04  0.090868   435 -0.486513     False    False  0.177915

# %%
dfo['CM'] = (dfo['b_y'] - dfo['b_x']).__abs__()

# %%
obs = np.array([
    ((dfo['faster_x']==True) & (dfo['faster_y']==True)).sum(),
    ((dfo['faster_x']==True) & (dfo['faster_y']==False)).sum(),
    ((dfo['faster_x']==False) & (dfo['faster_y']==True)).sum(),
    ((dfo['faster_x']==False) & (dfo['faster_y']==False)).sum(),
])
obs
# Out:
# array([3483, 1434, 2385, 3939])

# %%
obs/obs.sum()
# Out:
# array([0.30984788, 0.12756872, 0.21216974, 0.35041366])

# %%
exp = np.array([obs.mean()]*len(obs))
exp, exp.sum()
# Out:
# (array([2810.25, 2810.25, 2810.25, 2810.25]), np.float64(11241.0))

# %%
chisquare(f_obs=obs, f_exp=exp)
# Out:
# Power_divergenceResult(statistic=np.float64(1352.751801441153), pvalue=np.float64(5.266819521910178e-293))

# %% [markdown]
# ## Hypothesis test: CANDOR is equivalent to the rest of the study

# %%
candor_obs = np.array([
    ((dfo['faster_x'].loc[dfo['corpus'].isin(['CANDOR'])]==True) & (dfo['faster_y'].loc[dfo['corpus'].isin(['CANDOR'])]==True)).sum(),
    ((dfo['faster_x'].loc[dfo['corpus'].isin(['CANDOR'])]==True) & (dfo['faster_y'].loc[dfo['corpus'].isin(['CANDOR'])]==False)).sum(),
    ((dfo['faster_x'].loc[dfo['corpus'].isin(['CANDOR'])]==False) & (dfo['faster_y'].loc[dfo['corpus'].isin(['CANDOR'])]==True)).sum(),
    ((dfo['faster_x'].loc[dfo['corpus'].isin(['CANDOR'])]==False) & (dfo['faster_y'].loc[dfo['corpus'].isin(['CANDOR'])]==False)).sum(),
])
candor_obs
# Out:
# array([1651,   77,  995,  589])

# %%
exp = (obs/obs.sum()) * candor_obs.sum()
exp
# Out:
# array([1026.21617294,  422.50760608,  702.70616493, 1160.57005604])

# %%
chisquare(f_obs=candor_obs,f_exp=exp)
# Out:
# Power_divergenceResult(statistic=np.float64(1065.9970814871297), pvalue=np.float64(8.667618682365903e-231))

# %% [markdown]
# ## CANDOR conversation types yield different survey outcomes

# %%
df = dfo.loc[dfo['corpus'].isin(['CANDOR'])]

# %%
df.shape
# Out:
# (3312, 12)

# %%
df['cid'] = ['-'.join(it.split('-')[2:]) for it in df['cid']]

# %%
df.head()
# Out:
#       corpus                                   cid                   speaker  \
# 5499  CANDOR  142c436c-0d8f-49ee-9725-291486519f67  5eef7517c8692d20c3279493
# 5500  CANDOR  142c436c-0d8f-49ee-9725-291486519f67  5ef6bb87b83f3b000a3f04ae
# 5501  CANDOR  8bf5b973-cb87-4d3b-859b-8e116476295f  5f23ff398626c51fdd6c3fb5
# 5502  CANDOR  8bf5b973-cb87-4d3b-859b-8e116476295f  5f5eac716f1f7176f11d2bf0
# 5503  CANDOR  ea342a4f-891d-4717-8fb3-30bd1dadeca0  5b11682bd3ef5a000107dc58
#
#       self         a       b_x      k        b_  faster_x faster_y       b_y  \
# 5499  True  0.001407 -0.457402   4656 -0.486513     False     True -0.707541
# 5500  True  0.003729 -0.690014   4753 -0.486513      True    False -0.370920
# 5501  True  0.000994 -0.557747  16110 -0.486513      True     True -0.477524
# 5502  True  0.000069 -0.257256  15931 -0.486513     False    False -0.309996
# 5503  True  0.000142 -0.323722  48609 -0.486513     False    False -0.268295
#
#             CM
# 5499  0.250139
# 5500  0.319093
# 5501  0.080223
# 5502  0.052740
# 5503  0.055427

# %% [markdown]
# ### Merge with CANDOR survey data

# %%
vars = [
    ### Affective motive
    'best_affect', 'conv_leader', 'conversationalist', 'how_enjoyable', 'in_common', 'i_like_you', 'i_felt_close_to_my_partner', 'i_think_your_status', 'i_would_like_to_become_friends', 'overall_affect',
    'responsive_1','responsive_2','responsive_3',
    'you_are_friendly','you_are_good_listener', 'you_are_intelligent','you_are_kind', 'you_are_quickwitted','you_are_warm','you_like_me',

    ### Cognitive motives
    'anticipated_each_other_sr6', 'developed_joint_perspective_sr2', 'our_thoughts_synced_up_sr1', 'saw_world_in_same_way_sr8', 'shared_reality', 'thoughts_became_more_alike_sr5'
]

# %%
dfm = pd.read_csv(candor_meta_data_path)[['user_id', 'convo_id']+vars]
print(dfm.shape)
dfm.head()
# Out:
# (3312, 28)
#                     user_id                              convo_id  \
# 0  5efbe4f0c9f37c1a3b70afaf  56f21a75-4e86-4dee-9a15-a4f68e86e1a3
# 1  5f26378609aca228dcfd19fa  56f21a75-4e86-4dee-9a15-a4f68e86e1a3
# 2  5d8e361e6e920e0014b459d9  94a1abaa-d89e-4d0d-82ad-1c8de8155a2f
# 3  5f4d435c030fef9d0136b496  94a1abaa-d89e-4d0d-82ad-1c8de8155a2f
# 4  5ca6bbf13b5fcf00100996e9  4e3233b7-5d89-47e9-a795-25452f99a1c9
#
#    best_affect  conv_leader  conversationalist  how_enjoyable  in_common  \
# 0          7.0          6.0               76.0            7.0        7.0
# 1          7.0          7.0               73.0            7.0        8.0
# 2          7.0          3.0               33.0            5.0        1.0
# 3          5.0          8.0               65.0            4.0        3.0
# 4          9.0          4.0               96.0            9.0        6.0
#
#    i_like_you  i_felt_close_to_my_partner  i_think_your_status  ...  \
# 0         6.0                         NaN                  8.0  ...
# 1         5.0                         NaN                  6.0  ...
# 2         4.0                         NaN                  4.0  ...
# 3         5.0                         NaN                  6.0  ...
# 4         7.0                         6.0                  6.0  ...
#
#    you_are_kind  you_are_quickwitted  you_are_warm  you_like_me  \
# 0           9.0                  6.0           9.0          6.0
# 1           9.0                  8.0           9.0          6.0
# 2           2.0                  2.0           2.0          4.0
# 3           9.0                  9.0           9.0          5.0
# 4           9.0                  8.0           9.0          7.0
#
#    anticipated_each_other_sr6  developed_joint_perspective_sr2  \
# 0                         5.0                              7.0
# 1                         6.0                              5.0
# 2                         1.0                              1.0
# 3                         1.0                              2.0
# 4                         5.0                              3.0
#
#    our_thoughts_synced_up_sr1  saw_world_in_same_way_sr8  shared_reality  \
# 0                         5.0                        4.0           5.375
# 1                         6.0                        7.0           5.875
# 2                         1.0                        2.0           2.375
# 3                         2.0                        1.0           2.000
# 4                         4.0                        4.0           4.500
#
#    thoughts_became_more_alike_sr5
# 0                             6.0
# 1                             4.0
# 2                             2.0
# 3                             1.0
# 4                             5.0
#
# [5 rows x 28 columns]

# %% [markdown]
# #### Testing for normalcy

# %%
normalcy_and_other_stats = []

# %%
for var in vars:
    sel = dfm[var].isna()
    maxima = dfm[var].loc[~sel].max()
    minima = dfm[var].loc[~sel].min()
    medi = dfm[var].loc[~sel].median()
    mu = dfm[var].loc[~sel].mean()
    mode = dfm[var].loc[~sel].mode()
    skew_stat, p_skew = skewtest(dfm[var].loc[~sel].values)

    dv = dfm[var].loc[~sel].value_counts()
    chi_stat, p_chi = chisquare(f_obs=dv.values, f_exp=np.array([1/len(dv)]*len(dv))*dv.sum())

    normalcy_and_other_stats += [
        {
            'variable': var,
            'range': '[{}, {}]'.format(minima, maxima),
            'median': medi.item(),
            'mean': mu.item(),
            'mode': mode.values,
            'skew_stat': skew_stat, 'skew_p': p_skew,
            'chi_stat': chi_stat, 'chi_p': p_chi
        }
    ]

normalcy_and_other_stats = pd.DataFrame(normalcy_and_other_stats)

# %%
normalcy_and_other_stats.head(n=40)
# Out:
#                            variable         range  median       mean    mode  \
# 0                       best_affect    [1.0, 9.0]    8.00   7.830826   [9.0]
# 1                       conv_leader    [1.0, 9.0]    5.00   4.912803   [5.0]
# 2                 conversationalist  [0.0, 100.0]   79.00  73.885477  [90.0]
# 3                     how_enjoyable    [1.0, 9.0]    8.00   7.411115   [9.0]
# 4                         in_common    [1.0, 9.0]    6.00   5.891004   [7.0]
# 5                        i_like_you    [1.0, 7.0]    6.00   5.995088   [7.0]
# 6        i_felt_close_to_my_partner    [1.0, 7.0]    5.00   4.909976   [6.0]
# 7               i_think_your_status   [1.0, 10.0]    6.00   5.911548   [5.0]
# 8    i_would_like_to_become_friends    [1.0, 7.0]    5.00   4.970803   [6.0]
# 9                    overall_affect    [1.0, 9.0]    7.00   7.323611   [7.0]
# 10                     responsive_1    [1.0, 7.0]    6.00   5.714373   [6.0]
# 11                     responsive_2    [1.0, 7.0]    6.00   5.751229   [6.0]
# 12                     responsive_3    [1.0, 7.0]    6.00   5.942260   [6.0]
# 13                 you_are_friendly    [1.0, 9.0]    8.00   8.081670   [9.0]
# 14            you_are_good_listener    [1.0, 9.0]    8.00   7.534541   [7.0]
# 15              you_are_intelligent    [1.0, 9.0]    8.00   7.674854   [8.0]
# 16                     you_are_kind    [1.0, 9.0]    8.00   7.976052   [9.0]
# 17              you_are_quickwitted    [1.0, 9.0]    7.00   7.050660   [7.0]
# 18                     you_are_warm    [1.0, 9.0]    8.00   7.833589   [9.0]
# 19                      you_like_me    [1.0, 7.0]    5.00   5.350936   [5.0]
# 20       anticipated_each_other_sr6    [1.0, 7.0]    4.00   3.636057   [4.0]
# 21  developed_joint_perspective_sr2    [1.0, 7.0]    5.00   4.920455   [5.0]
# 22       our_thoughts_synced_up_sr1    [1.0, 7.0]    4.00   4.088452   [5.0]
# 23        saw_world_in_same_way_sr8    [1.0, 7.0]    5.00   4.815725   [5.0]
# 24                   shared_reality    [1.0, 7.0]    4.75   4.710458  [4.75]
# 25   thoughts_became_more_alike_sr5    [1.0, 7.0]    5.00   4.757371   [5.0]
#
#     skew_stat         skew_p     chi_stat          chi_p
# 0  -20.435809   8.035056e-93  4714.587657   0.000000e+00
# 1   -0.177222   8.593339e-01  1118.964691  3.072156e-236
# 2  -22.179386  5.431503e-109  6551.635554   0.000000e+00
# 3  -22.780117  7.219819e-115  3218.084126   0.000000e+00
# 4  -10.400025   2.478679e-25  1141.369358  4.447494e-241
# 5  -23.672436  6.934913e-124  3718.741787   0.000000e+00
# 6   -8.470986   2.433243e-17   341.532847   1.013785e-70
# 7   -1.936587   5.279590e-02  2895.382064   0.000000e+00
# 8   -7.628042   2.383459e-14   254.569343   4.328281e-52
# 9  -13.989633   1.803392e-44  3368.975745   0.000000e+00
# 10 -25.225802  2.087852e-140  4371.540541   0.000000e+00
# 11 -22.391138  4.801695e-111  4208.124079   0.000000e+00
# 12 -27.795393  4.931125e-170  4908.145577   0.000000e+00
# 13 -29.299354  1.056971e-188  6514.184219   0.000000e+00
# 14 -25.313454  2.271250e-141  4712.531778   0.000000e+00
# 15 -23.015321  3.274352e-117  4304.572306   0.000000e+00
# 16 -25.850179  2.421877e-147  5639.562174   0.000000e+00
# 17 -19.696448   2.312901e-86  2422.751612   0.000000e+00
# 18 -26.682087  7.597236e-157  5018.410193   0.000000e+00
# 19 -13.983543   1.964583e-44  2348.082898   0.000000e+00
# 20   2.765348   5.686216e-03   543.275799  3.974729e-114
# 21 -15.804049   2.917588e-56  1581.773956   0.000000e+00
# 22  -5.113544   3.161703e-07  1065.425061  6.301933e-227
# 23 -13.365589   9.607189e-41  1265.853808  2.669239e-270
# 24 -11.940655   7.264922e-33  1855.771499   0.000000e+00
# 25 -12.686214   7.051321e-37  1109.557740  1.783913e-236

# %%
normalcy_and_other_stats.to_csv('candor-normalcy-stats.csv', index=False, encoding='utf-8')

# %% [markdown]
# #### Merging docs

# %%
df = pd.merge(
    left=df, left_on=['speaker', 'cid'],
    right=dfm, right_on=['user_id', 'convo_id'],
    # left=results, left_on=['speaker'],
    # right=dfm, right_on=['user_id'],
    how='left'
)

# %%
df = df.drop(columns=['user_id', 'convo_id'])
# results = results.drop(columns=['user_id'])
# results.columns
df.isna().sum()
# Out:
# corpus                                0
# cid                                   0
# speaker                               0
# self                                  0
# a                                     0
# b_x                                   0
# k                                     0
# b_                                    0
# faster_x                              0
# faster_y                              0
# b_y                                   0
# CM                                    0
# best_affect                          55
# conv_leader                          55
# conversationalist                    55
# how_enjoyable                        55
# in_common                            55
# i_like_you                           55
# i_felt_close_to_my_partner         2490
# i_think_your_status                  56
# i_would_like_to_become_friends     2490
# overall_affect                       55
# responsive_1                         56
# responsive_2                         56
# responsive_3                         56
# you_are_friendly                     55
# you_are_good_listener                55
# you_are_intelligent                  55
# you_are_kind                         55
# you_are_quickwitted                  55
# you_are_warm                         55
# you_like_me                          55
# anticipated_each_other_sr6           56
# developed_joint_perspective_sr2      56
# our_thoughts_synced_up_sr1           56
# saw_world_in_same_way_sr8            56
# shared_reality                       56
# thoughts_became_more_alike_sr5       56
# dtype: int64

# %% [markdown]
# ## Tests

# %% [markdown]
# ##### Convert values to ints for intercepts

# %%
## convert speaker to integers
col = 'speaker'
vs = df[col].unique()
# sid = {sp:i+1 for i,sp in enumerate(np.random.choice(vs,size=(len(vs),),replace=False))}
sid = {sp:i+1 for i,sp in enumerate(vs)}
df[col+'_'] = [sid[sp] for sp in tqdm(df[col])]
# Out:
#   0%|          | 0/3312 [00:00<?, ?it/s]

# %%
## convert convo_id col to integers
col = 'cid'
vs = df[col].unique()
# sid = {sp:i+1 for i,sp in enumerate(np.random.choice(vs,size=(len(vs),),replace=False))}
sid = {sp:i+1 for i,sp in enumerate(vs)}
df[col+'_'] = [sid[sp] for sp in tqdm(df[col])]
# Out:
#   0%|          | 0/3312 [00:00<?, ?it/s]

# %% [markdown]
# ### Model in R

# %%
def random_effects_df(x):
    output = np.array(str(x).split()[:-2]).reshape(-1,3)
    odf = pd.DataFrame()
    odf['se'] = output[1:,-1].astype(float)
    odf.index = output[1:,0]
    return odf

# %%
##########################################
## A set of resids to show ∇H / t
##########################################
# formula = "b ~ v_s + v_o + (1|self) + (1|speaker_)"
# formula = "b ~ v_s + self + v_o + other + (1|speaker_) + (1|cid_) -1"
formula = "{} ~ CM"
# model = "Hxy ~ nx + ny"
# model = "Hxy ~ nx + ny + null"
##########################################

# %%
df_all = []

# %%
for var in vars:
    sel_2 = ~df[var].isna()

    FO = Formula(formula.format(var))
    # model_ = str(model_script)

    with localconverter(default_converter + pandas2ri.converter):
        df_ = conversion.py2rpy(df[[var, 'faster_x', 'faster_y', 'speaker_', 'cid_', 'CM']].loc[sel_2])

    ro.globalenv['df'] = df_
    ro.globalenv['formula'] = FO

    ro.r("""
    library(lme4)
    # print(colnames(df))

    # model <- lmer(formula, data=df)
    model <- glm(formula, data=df)
    summarization <- summary(model)
    """)

    summary = ro.r('summarization')

    # ro.r('cov_vals <- vcov(model)')
    # covar = ro.r('cov_vals')
    # covar_df = pd.DataFrame(pandas2ri.rpy2py(covar))
    # covar_df.index = list(covar.names[0])
    # covar_df.columns = list(covar.names[1])
    # covar_df.head(n=10)
    #
    # re_effects_df = random_effects_df(summary.rx2('varcor'))
    # re_effects_df.index = ['(1|{})'.format(idx) for idx in re_effects_df.index]

    fixed_effects = summary.rx2('coefficients')
    fixed_effects_df = pd.DataFrame(pandas2ri.rpy2py(fixed_effects))
    fixed_effects_df.index = list(fixed_effects.names[0])
    fixed_effects_df.columns = list(fixed_effects.names[1])
    fixed_effects_df = fixed_effects_df.rename(columns={'Std. Error': 'se'})



    df_params = pd.concat([
        fixed_effects_df,
        # re_effects_df,
        # covar_df
    ],axis=1)
    df_params['k'] = sel_2.sum()
    # df_params['p'] = [t.sf(tstat.__abs__(), df=(k-1)) for tstat, k in df_params[['t value', 'k']].values]
    df_params['var'] = df_params.index.values
    df_params['survey_var'] = var

    df_all += [df_params]
df_all = pd.concat(df_all,ignore_index=True)

# sort and preamble
preambulatory = ['survey_var', 'var']
df_all = df_all[preambulatory+[col for col in list(df_all) if col not in preambulatory]]

# %%
df_all.loc[~df_all['var'].isin(['(Intercept)'])].head(n=50)
# Out:
#                          survey_var var  Estimate        se   t value  \
# 1                       best_affect  CM  0.070853  0.111846  0.633488
# 3                       conv_leader  CM -0.228063  0.188914 -1.207234
# 5                 conversationalist  CM  1.158402  1.898894  0.610040
# 7                     how_enjoyable  CM  0.019043  0.144820  0.131493
# 9                         in_common  CM -0.194659  0.182173 -1.068539
# 11                       i_like_you  CM  0.059918  0.109192  0.548738
# 13       i_felt_close_to_my_partner  CM  0.656459  0.916540  0.716236
# 15              i_think_your_status  CM -0.006647  0.140338 -0.047361
# 17   i_would_like_to_become_friends  CM  0.926870  0.929240  0.997449
# 19                   overall_affect  CM  0.139544  0.122566  1.138518
# 21                     responsive_1  CM -0.071069  0.099393 -0.715030
# 23                     responsive_2  CM -0.087862  0.096133 -0.913967
# 25                     responsive_3  CM -0.088382  0.093065 -0.949677
# 27                 you_are_friendly  CM  0.036101  0.111759  0.323025
# 29            you_are_good_listener  CM  0.148213  0.114952  1.289339
# 31              you_are_intelligent  CM  0.093440  0.117920  0.792400
# 33                     you_are_kind  CM  0.050827  0.112831  0.450471
# 35              you_are_quickwitted  CM  0.095999  0.155718  0.616495
# 37                     you_are_warm  CM  0.071396  0.131517  0.542867
# 39                      you_like_me  CM -0.035819  0.111434 -0.321433
# 41       anticipated_each_other_sr6  CM  0.090926  0.153945  0.590639
# 43  developed_joint_perspective_sr2  CM  0.033333  0.137389  0.242619
# 45       our_thoughts_synced_up_sr1  CM -0.151689  0.140918 -1.076433
# 47        saw_world_in_same_way_sr8  CM -0.022400  0.140229 -0.159740
# 49                   shared_reality  CM -0.005494  0.110738 -0.049615
# 51   thoughts_became_more_alike_sr5  CM -0.045300  0.144365 -0.313787
#
#     Pr(>|t|)     k
# 1   0.526459  3257
# 3   0.227430  3257
# 5   0.541878  3257
# 7   0.895394  3257
# 9   0.285357  3257
# 11  0.583223  3257
# 13  0.474049   822
# 15  0.962228  3256
# 17  0.318841   822
# 19  0.254988  3257
# 21  0.474642  3256
# 23  0.360802  3256
# 25  0.342347  3256
# 27  0.746697  3257
# 29  0.197372  3257
# 31  0.428185  3257
# 33  0.652401  3257
# 35  0.537611  3257
# 37  0.587259  3257
# 39  0.747903  3257
# 41  0.554804  3256
# 43  0.808316  3256
# 45  0.281814  3256
# 47  0.873096  3256
# 49  0.960432  3256
# 51  0.753703  3256

# %%
df_all.to_csv('regression_estimates.csv', index=False, encoding='utf-8')
